# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files
_ = files.upload()
# Out:
#      <input type="file" id="files-d496a921-e55d-4d84-a7d7-1ccdeca97e81" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d496a921-e55d-4d84-a7d7-1ccdeca97e81">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving train.py to train.py

# %%
from train import train
out_dir = "/content/drive/MyDrive/MLO_proj/results"
pretrained_clf_path='/content/drive/MyDrive/MLO_proj/Data/models/mnist.pth'

args = dict(epochs = 1,
            batch_size = 256,
            optim = 'Adam',
            lr = 0.001,
            betas = (0.5, 0.999), #0.05?
            lookahead = False,
            lookahead_k = 5,
            eval_avg = False,
            n_workers = 2,
            device = 'cuda',
            grad_max_norm = None,
            seed = 42,
            continue_training = False)

train(args, out_dir, pretrained_clf_path)
# Out:
# ...
# Extracting datasets/MNIST/raw/train-images-idx3-ubyte.gz to datasets/MNIST/raw
#
# ...
# Extracting datasets/MNIST/raw/train-labels-idx1-ubyte.gz to datasets/MNIST/raw
#
# ...
# Failed to download (trying next):
# HTTP Error 503: Service Unavailable
#
# ...
# Extracting datasets/MNIST/raw/t10k-images-idx3-ubyte.gz to datasets/MNIST/raw
#
# ...
# Extracting datasets/MNIST/raw/t10k-labels-idx1-ubyte.gz to datasets/MNIST/raw
#
# Processing...
# Done!
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/mnist.py:502: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:143.)
# ...

# %%
from train import train
out_dir = "/content/drive/MyDrive/MLO_proj/results"
pretrained_clf_path='/content/drive/MyDrive/MLO_proj/Data/models/mnist.pth'

args = dict(epochs = 3,
            batch_size = 256,
            optim = 'ExtraAdam', #from ['Adam', 'ExtraAdam']
            lr = 0.001,
            betas = (0.5, 0.999), #0.05?
            lookahead = True,
            lookahead_k = 5,
            eval_avg = False,
            n_workers = 2,
            device = 'cuda',
            grad_max_norm = None,
            seed = 42,
            continue_training = False)

train(args, out_dir, pretrained_clf_path)
# Out:
# Loading trained model from /content/drive/MyDrive/MLO_proj/Data/models/mnist.pth
# Epoch 0: Mean proba from D(G(z)): 0.3671 +/- 0.0963
# Epoch 1: Mean proba from D(G(z)): 0.5077 +/- 0.0973
# Epoch 2: Mean proba from D(G(z)): 0.5330 +/- 0.0909
